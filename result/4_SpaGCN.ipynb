# %%
from d_SpaGCN.run import train, train_spg
from dataset import *
from tools import evaluate
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %% [markdown]
# # human breast cancer

# %%
adata, n_cluster = get_human_breast_cancer_data()
train_spg(adata, n_cluster)
evaluate(adata, pred_list=['pred', 'refined_pred'])
# Out:
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: human_breast_cancer, size: (3798, 36601), cluster: 20.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 83.64162436864945]
# Run 2: l [0.01, 500.005], p [0.0, 21.58456802368164]
# Run 3: l [0.01, 250.0075], p [0.0, 4.846828460693359]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 0.5336281061172485]
# Run 5: l [62.509375, 125.00874999999999], p [0.00040018558502197266, 0.5336281061172485]
# Run 6: l [93.7590625, 125.00874999999999], p [0.0820695161819458, 0.5336281061172485]
# Run 7: l [109.38390625, 125.00874999999999], p [0.2545154094696045, 0.5336281061172485]
# Run 8: l [117.196328125, 125.00874999999999], p [0.3819239139556885, 0.5336281061172485]
# Run 9: l [121.1025390625, 125.00874999999999], p [0.4549444913864136, 0.5336281061172485]
# recommended l =  123.05564453125
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  12
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  12
# Res changed to 0.7999999999999999
# Initializing cluster centers with louvain, resolution =  0.8999999999999999
# Epoch  0
# Epoch  10
# Res =  0.8999999999999999 Num of clusters =  13
# Res changed to 0.8999999999999999
# Initializing cluster centers with louvain, resolution =  0.9999999999999999
# Epoch  0
# Epoch  10
# Res =  0.9999999999999999 Num of clusters =  13
# Res changed to 0.9999999999999999
# Initializing cluster centers with louvain, resolution =  1.0999999999999999
# Epoch  0
# Epoch  10
# Res =  1.0999999999999999 Num of clusters =  15
# Res changed to 1.0999999999999999
# Initializing cluster centers with louvain, resolution =  1.2
# Epoch  0
# Epoch  10
# Res =  1.2 Num of clusters =  17
# Res changed to 1.2
# Initializing cluster centers with louvain, resolution =  1.3
# Epoch  0
# Epoch  10
# Res =  1.3 Num of clusters =  17
# Res changed to 1.3
# Initializing cluster centers with louvain, resolution =  1.4000000000000001
# Epoch  0
# Epoch  10
# Res =  1.4000000000000001 Num of clusters =  20
# recommended res =  1.4000000000000001
# Initializing cluster centers with louvain, resolution =  1.4000000000000001
# Epoch  0
# Epoch  10
# Epoch  20
# delta_label  0.003686150605581885 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 28
# Calculateing adj matrix using xy only...
# >>> pred: 57.9307
# >>> refined_pred: 59.2489

# %% [markdown]
# # DLPFC

# %%
for i in range(12):
    adata, n_cluster = get_dlpfc_data(i)
    train_spg(adata, n_cluster)
    evaluate(adata, pred_list=['pred', 'refined_pred'])
# Out:
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151507, size: (4226, 33538), cluster: 7.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 312.00739089512916]
# Run 2: l [0.01, 500.005], p [0.0, 85.49689483642578]
# Run 3: l [0.01, 250.0075], p [0.0, 21.679431915283203]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.808452129364014]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5168116092681885]
# Run 6: l [31.2596875, 62.509375], p [0.0003445148468017578, 0.5168116092681885]
# Run 7: l [46.884531249999995, 62.509375], p [0.07710742950439453, 0.5168116092681885]
# Run 8: l [54.69695312499999, 62.509375], p [0.24361300468444824, 0.5168116092681885]
# Run 9: l [58.6031640625, 62.509375], p [0.3679589033126831, 0.5168116092681885]
# Run 10: l [60.556269531249995, 62.509375], p [0.43952035903930664, 0.5168116092681885]
# Run 11: l [61.532822265625, 62.509375], p [0.47747576236724854, 0.5168116092681885]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  5
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  7
# recommended res =  0.7999999999999999
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# Epoch  110
# Epoch  120
# delta_label  0.00473260766682442 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 121
# Calculateing adj matrix using xy only...
# >>> pred: 42.8681
# >>> refined_pred: 45.7632
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151508, size: (4384, 33538), cluster: 7.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 313.0379008820827]
# Run 2: l [0.01, 500.005], p [0.0, 85.58491516113281]
# Run 3: l [0.01, 250.0075], p [0.0, 21.68450164794922]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.809234619140625]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5169980525970459]
# Run 6: l [31.2596875, 62.509375], p [0.00034499168395996094, 0.5169980525970459]
# Run 7: l [46.884531249999995, 62.509375], p [0.07715213298797607, 0.5169980525970459]
# Run 8: l [54.69695312499999, 62.509375], p [0.2437218427658081, 0.5169980525970459]
# Run 9: l [58.6031640625, 62.509375], p [0.36810553073883057, 0.5169980525970459]
# Run 10: l [60.556269531249995, 62.509375], p [0.43968665599823, 0.5169980525970459]
# Run 11: l [61.532822265625, 62.509375], p [0.4776519536972046, 0.5169980525970459]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  6
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  7
# recommended res =  0.7999999999999999
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# Epoch  110
# Epoch  120
# Epoch  130
# Epoch  140
# Epoch  150
# Epoch  160
# Epoch  170
# Epoch  180
# Epoch  190
# Calculateing adj matrix using xy only...
# >>> pred: 39.4218
# >>> refined_pred: 43.1043
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151509, size: (4789, 33538), cluster: 7.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 311.427603618283]
# Run 2: l [0.01, 500.005], p [0.0, 84.65625]
# Run 3: l [0.01, 250.0075], p [0.0, 21.38892364501953]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.7252197265625]
# recommended l =  62.509375
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  7
# recommended res =  0.7
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# Epoch  110
# Epoch  120
# Epoch  130
# Epoch  140
# Epoch  150
# Epoch  160
# Epoch  170
# Epoch  180
# Epoch  190
# Calculateing adj matrix using xy only...
# >>> pred: 41.7149
# >>> refined_pred: 43.1945
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151510, size: (4634, 33538), cluster: 7.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 311.96597550300635]
# Run 2: l [0.01, 500.005], p [0.0, 84.9486083984375]
# Run 3: l [0.01, 250.0075], p [0.0, 21.482959747314453]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.754456043243408]
# recommended l =  62.509375
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  5
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  6
# Res changed to 0.7999999999999999
# Initializing cluster centers with louvain, resolution =  0.8999999999999999
# Epoch  0
# Epoch  10
# Res =  0.8999999999999999 Num of clusters =  7
# recommended res =  0.8999999999999999
# Initializing cluster centers with louvain, resolution =  0.8999999999999999
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# Epoch  110
# Epoch  120
# Epoch  130
# Epoch  140
# Epoch  150
# Epoch  160
# Epoch  170
# Epoch  180
# Epoch  190
# Calculateing adj matrix using xy only...
# >>> pred: 40.6352
# >>> refined_pred: 42.3118
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151669, size: (3661, 33538), cluster: 5.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 303.8774432377918]
# Run 2: l [0.01, 500.005], p [0.0, 83.65432739257812]
# Run 3: l [0.01, 250.0075], p [0.0, 21.296619415283203]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.740560531616211]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5103416442871094]
# Run 6: l [31.2596875, 62.509375], p [0.0003401041030883789, 0.5103416442871094]
# Run 7: l [46.884531249999995, 62.509375], p [0.07613587379455566, 0.5103416442871094]
# Run 8: l [54.69695312499999, 62.509375], p [0.24055945873260498, 0.5103416442871094]
# Run 9: l [58.6031640625, 62.509375], p [0.3633519411087036, 0.5103416442871094]
# Run 10: l [60.556269531249995, 62.509375], p [0.4340183734893799, 0.5103416442871094]
# Run 11: l [61.532822265625, 62.509375], p [0.4714987277984619, 0.5103416442871094]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  6
# Initializing cluster centers with louvain, resolution =  0.6
# Epoch  0
# Epoch  10
# Res =  0.6 Num of clusters =  6
# Res changed to 0.6
# Initializing cluster centers with louvain, resolution =  0.5
# Epoch  0
# Epoch  10
# Res =  0.5 Num of clusters =  4
# Step changed to 0.05
# Initializing cluster centers with louvain, resolution =  0.5499999999999999
# Epoch  0
# Epoch  10
# Res =  0.5499999999999999 Num of clusters =  5
# recommended res =  0.5499999999999999
# Initializing cluster centers with louvain, resolution =  0.5499999999999999
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# delta_label  0.004916689429117728 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 109
# Calculateing adj matrix using xy only...
# >>> pred: 27.6914
# >>> refined_pred: 30.3469
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151670, size: (3498, 33538), cluster: 5.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 304.4529761723347]
# Run 2: l [0.01, 500.005], p [0.0, 84.13076782226562]
# Run 3: l [0.01, 250.0075], p [0.0, 21.441434860229492]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.772664546966553]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5138150453567505]
# Run 6: l [31.2596875, 62.509375], p [0.0003432035446166992, 0.5138150453567505]
# Run 7: l [46.884531249999995, 62.509375], p [0.07670390605926514, 0.5138150453567505]
# Run 8: l [54.69695312499999, 62.509375], p [0.24225592613220215, 0.5138150453567505]
# Run 9: l [58.6031640625, 62.509375], p [0.3658638000488281, 0.5138150453567505]
# Run 10: l [60.556269531249995, 62.509375], p [0.4369940757751465, 0.5138150453567505]
# Run 11: l [61.532822265625, 62.509375], p [0.4747190475463867, 0.5138150453567505]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  4
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  5
# recommended res =  0.7999999999999999
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# Epoch  110
# Epoch  120
# Epoch  130
# Epoch  140
# delta_label  0.004288164665523156 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 145
# Calculateing adj matrix using xy only...
# >>> pred: 29.1969
# >>> refined_pred: 31.0453
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151671, size: (4110, 33538), cluster: 5.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 310.4714764706403]
# Run 2: l [0.01, 500.005], p [0.0, 85.17036437988281]
# Run 3: l [0.01, 250.0075], p [0.0, 21.613140106201172]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.797861576080322]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5156970024108887]
# Run 6: l [31.2596875, 62.509375], p [0.0003432035446166992, 0.5156970024108887]
# Run 7: l [46.884531249999995, 62.509375], p [0.07690870761871338, 0.5156970024108887]
# Run 8: l [54.69695312499999, 62.509375], p [0.2430485486984253, 0.5156970024108887]
# Run 9: l [58.6031640625, 62.509375], p [0.36713922023773193, 0.5156970024108887]
# Run 10: l [60.556269531249995, 62.509375], p [0.43855786323547363, 0.5156970024108887]
# Run 11: l [61.532822265625, 62.509375], p [0.4764382839202881, 0.5156970024108887]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  6
# Initializing cluster centers with louvain, resolution =  0.6
# Epoch  0
# Epoch  10
# Res =  0.6 Num of clusters =  5
# recommended res =  0.6
# Initializing cluster centers with louvain, resolution =  0.6
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# Epoch  110
# Epoch  120
# Epoch  130
# Epoch  140
# Epoch  150
# Epoch  160
# Epoch  170
# Epoch  180
# Epoch  190
# Calculateing adj matrix using xy only...
# >>> pred: 49.7267
# >>> refined_pred: 53.5025
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151672, size: (4015, 33538), cluster: 5.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 309.02506516689647]
# Run 2: l [0.01, 500.005], p [0.0, 84.78437042236328]
# Run 3: l [0.01, 250.0075], p [0.0, 21.497591018676758]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.774121284484863]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5137132406234741]
# Run 6: l [31.2596875, 62.509375], p [0.00034296512603759766, 0.5137132406234741]
# Run 7: l [46.884531249999995, 62.509375], p [0.07667315006256104, 0.5137132406234741]
# Run 8: l [54.69695312499999, 62.509375], p [0.24218857288360596, 0.5137132406234741]
# Run 9: l [58.6031640625, 62.509375], p [0.36577796936035156, 0.5137132406234741]
# Run 10: l [60.556269531249995, 62.509375], p [0.4368997812271118, 0.5137132406234741]
# Run 11: l [61.532822265625, 62.509375], p [0.474621057510376, 0.5137132406234741]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  6
# Initializing cluster centers with louvain, resolution =  0.6
# Epoch  0
# Epoch  10
# Res =  0.6 Num of clusters =  5
# recommended res =  0.6
# Initializing cluster centers with louvain, resolution =  0.6
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# Epoch  110
# Epoch  120
# Epoch  130
# Epoch  140
# Epoch  150
# Epoch  160
# Epoch  170
# Epoch  180
# Epoch  190
# Calculateing adj matrix using xy only...
# >>> pred: 53.8043
# >>> refined_pred: 56.2319
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151673, size: (3639, 33538), cluster: 7.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 304.1220175019325]
# Run 2: l [0.01, 500.005], p [0.0, 83.85807037353516]
# Run 3: l [0.01, 250.0075], p [0.0, 21.341144561767578]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.750619411468506]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5111031532287598]
# Run 6: l [31.2596875, 62.509375], p [0.0003393888473510742, 0.5111031532287598]
# Run 7: l [46.884531249999995, 62.509375], p [0.07618057727813721, 0.5111031532287598]
# Run 8: l [54.69695312499999, 62.509375], p [0.24083411693572998, 0.5111031532287598]
# Run 9: l [58.6031640625, 62.509375], p [0.36383748054504395, 0.5111031532287598]
# Run 10: l [60.556269531249995, 62.509375], p [0.4346342086791992, 0.5111031532287598]
# Run 11: l [61.532822265625, 62.509375], p [0.47218525409698486, 0.5111031532287598]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  6
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  8
# Step changed to 0.05
# Initializing cluster centers with louvain, resolution =  0.75
# Epoch  0
# Epoch  10
# Res =  0.75 Num of clusters =  8
# Step changed to 0.025
# Initializing cluster centers with louvain, resolution =  0.725
# Epoch  0
# Epoch  10
# Res =  0.725 Num of clusters =  7
# recommended res =  0.725
# Initializing cluster centers with louvain, resolution =  0.725
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# Epoch  110
# Epoch  120
# Epoch  130
# Epoch  140
# Epoch  150
# Epoch  160
# Epoch  170
# Epoch  180
# Epoch  190
# Calculateing adj matrix using xy only...
# >>> pred: 39.0781
# >>> refined_pred: 41.5448
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151674, size: (3673, 33538), cluster: 7.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 303.86047687500917]
# Run 2: l [0.01, 500.005], p [0.0, 83.68516540527344]
# Run 3: l [0.01, 250.0075], p [0.0, 21.29427146911621]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.7398552894592285]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5102378129959106]
# Run 6: l [31.2596875, 62.509375], p [0.0003401041030883789, 0.5102378129959106]
# Run 7: l [46.884531249999995, 62.509375], p [0.07612454891204834, 0.5102378129959106]
# Run 8: l [54.69695312499999, 62.509375], p [0.2405151128768921, 0.5102378129959106]
# Run 9: l [58.6031640625, 62.509375], p [0.36328089237213135, 0.5102378129959106]
# Run 10: l [60.556269531249995, 62.509375], p [0.433931827545166, 0.5102378129959106]
# Run 11: l [61.532822265625, 62.509375], p [0.47140347957611084, 0.5102378129959106]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  8
# Initializing cluster centers with louvain, resolution =  0.6
# Epoch  0
# Epoch  10
# Res =  0.6 Num of clusters =  7
# recommended res =  0.6
# Initializing cluster centers with louvain, resolution =  0.6
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# delta_label  0.0038115981486523277 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 40
# Calculateing adj matrix using xy only...
# >>> pred: 42.6258
# >>> refined_pred: 43.4699
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151675, size: (3592, 33538), cluster: 7.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 297.97099796262245]
# Run 2: l [0.01, 500.005], p [0.0, 82.79729461669922]
# Run 3: l [0.01, 250.0075], p [0.0, 21.207942962646484]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.7304368019104]
# recommended l =  62.509375
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  7
# recommended res =  0.7
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# Epoch  60
# Epoch  70
# Epoch  80
# Epoch  90
# Epoch  100
# Epoch  110
# Epoch  120
# Epoch  130
# Epoch  140
# Epoch  150
# Epoch  160
# Epoch  170
# Epoch  180
# Epoch  190
# Calculateing adj matrix using xy only...
# >>> pred: 32.7387
# >>> refined_pred: 34.6251
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# >>> dataset name: dlpfc, slice id: 151676, size: (3460, 33538), cluster: 7.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 302.06612445704735]
# Run 2: l [0.01, 500.005], p [0.0, 83.56209564208984]
# Run 3: l [0.01, 250.0075], p [0.0, 21.290042877197266]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.743496894836426]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5107473134994507]
# Run 6: l [31.2596875, 62.509375], p [0.0003401041030883789, 0.5107473134994507]
# Run 7: l [46.884531249999995, 62.509375], p [0.07618176937103271, 0.5107473134994507]
# Run 8: l [54.69695312499999, 62.509375], p [0.24073255062103271, 0.5107473134994507]
# Run 9: l [58.6031640625, 62.509375], p [0.3636287450790405, 0.5107473134994507]
# Run 10: l [60.556269531249995, 62.509375], p [0.43435657024383545, 0.5107473134994507]
# Run 11: l [61.532822265625, 62.509375], p [0.4718698263168335, 0.5107473134994507]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  6
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  6
# Res changed to 0.7999999999999999
# Initializing cluster centers with louvain, resolution =  0.8999999999999999
# Epoch  0
# Epoch  10
# Res =  0.8999999999999999 Num of clusters =  8
# Step changed to 0.05
# Initializing cluster centers with louvain, resolution =  0.85
# Epoch  0
# Epoch  10
# Res =  0.85 Num of clusters =  8
# Step changed to 0.025
# Initializing cluster centers with louvain, resolution =  0.825
# Epoch  0
# Epoch  10
# Res =  0.825 Num of clusters =  8
# Step changed to 0.0125
# Initializing cluster centers with louvain, resolution =  0.8124999999999999
# Epoch  0
# Epoch  10
# Res =  0.8124999999999999 Num of clusters =  8
# Step changed to 0.00625
# Initializing cluster centers with louvain, resolution =  0.8062499999999999
# Epoch  0
# Epoch  10
# Res =  0.8062499999999999 Num of clusters =  6
# Res changed to 0.8062499999999999
# Initializing cluster centers with louvain, resolution =  0.8124999999999999
# Epoch  0
# Epoch  10
# Res =  0.8124999999999999 Num of clusters =  8
# Step changed to 0.003125
# Initializing cluster centers with louvain, resolution =  0.809375
# Epoch  0
# Epoch  10
# Res =  0.809375 Num of clusters =  8
# Step changed to 0.0015625
# Initializing cluster centers with louvain, resolution =  0.8078124999999999
# Epoch  0
# Epoch  10
# Res =  0.8078124999999999 Num of clusters =  6
# Res changed to 0.8078124999999999
# Initializing cluster centers with louvain, resolution =  0.809375
# Epoch  0
# Epoch  10
# Res =  0.809375 Num of clusters =  8
# Step changed to 0.00078125
# Initializing cluster centers with louvain, resolution =  0.8085937499999999
# Epoch  0
# Epoch  10
# Res =  0.8085937499999999 Num of clusters =  7
# recommended res =  0.8085937499999999
# Initializing cluster centers with louvain, resolution =  0.8085937499999999
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# Epoch  40
# Epoch  50
# delta_label  0.004335260115606936 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 58
# Calculateing adj matrix using xy only...
# >>> pred: 32.7240
# >>> refined_pred: 34.2277

# %% [markdown]
# # 10x Visium H&E

# %%
adata, n_cluster = get_visium_hne_data()
train_spg(adata, n_cluster)
evaluate(adata, pred_list=['pred', 'refined_pred'])
# Out:
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/scanpy/preprocessing/_highly_variable_genes.py:62: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(
# >>> dataset name: visium_hne, size: (2688, 18078), cluster: 15.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 293.8278243698919]
# Run 2: l [0.01, 500.005], p [0.0, 82.9404067993164]
# Run 3: l [0.01, 250.0075], p [0.0, 21.30322265625]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 4.75237512588501]
# Run 5: l [0.01, 62.509375], p [0.0, 0.5123445987701416]
# Run 6: l [31.2596875, 62.509375], p [0.00034427642822265625, 0.5123445987701416]
# Run 7: l [46.884531249999995, 62.509375], p [0.076590895652771, 0.5123445987701416]
# Run 8: l [54.69695312499999, 62.509375], p [0.24169254302978516, 0.5123445987701416]
# Run 9: l [58.6031640625, 62.509375], p [0.36490416526794434, 0.5123445987701416]
# Run 10: l [60.556269531249995, 62.509375], p [0.4357926845550537, 0.5123445987701416]
# Run 11: l [61.532822265625, 62.509375], p [0.4733865261077881, 0.5123445987701416]
# recommended l =  62.021098632812496
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  14
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  16
# Step changed to 0.05
# Initializing cluster centers with louvain, resolution =  0.75
# Epoch  0
# Epoch  10
# Res =  0.75 Num of clusters =  15
# recommended res =  0.75
# Initializing cluster centers with louvain, resolution =  0.75
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# delta_label  0.003720238095238095 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 37
# Calculateing adj matrix using xy only...
# >>> pred: 58.4931
# >>> refined_pred: 58.1170

# %% [markdown]
# # 10x Visium fluo

# %%
adata, n_cluster = get_visium_fluo_data()
train_spg(adata, n_cluster)
evaluate(adata, pred_list=['pred', 'refined_pred'])
# Out:
# /mnt/5280e/twang/.conda/envs/torch+pyg/lib/python3.8/site-packages/scanpy/preprocessing/_highly_variable_genes.py:62: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(
# >>> dataset name: visium_fluo, size: (2800, 16562), cluster: 15.
# Calculateing adj matrix using xy only...
# WARNING: adata.X seems to be already log-transformed.
# Run 1: l [0.01, 1000], p [0.0, 83.84293318471154]
# Run 2: l [0.01, 500.005], p [0.0, 21.5477294921875]
# Run 3: l [0.01, 250.0075], p [0.0, 4.811064720153809]
# Run 4: l [0.01, 125.00874999999999], p [0.0, 0.5216915607452393]
# Run 5: l [62.509375, 125.00874999999999], p [0.00036203861236572266, 0.5216915607452393]
# Run 6: l [93.7590625, 125.00874999999999], p [0.07866263389587402, 0.5216915607452393]
# Run 7: l [109.38390625, 125.00874999999999], p [0.24692749977111816, 0.5216915607452393]
# Run 8: l [117.196328125, 125.00874999999999], p [0.372114896774292, 0.5216915607452393]
# Run 9: l [121.1025390625, 125.00874999999999], p [0.44405531883239746, 0.5216915607452393]
# Run 10: l [123.05564453125, 125.00874999999999], p [0.4821876287460327, 0.5216915607452393]
# recommended l =  124.032197265625
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  14
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  15
# recommended res =  0.7999999999999999
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# delta_label  0.0035714285714285713 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 31
# Calculateing adj matrix using xy only...
# >>> pred: 65.9335
# >>> refined_pred: 65.2255
